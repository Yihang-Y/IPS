# %%
import numpy as np
import matplotlib.pyplot as plt
import helpers as hp

# %%
w = 1
x, p = hp.leapfrog_integrate(np.array([-1]), np.array([1]), 1000, 3, lambda x: -w**2 * x)
# Out:
# C:\Users\marka\AppData\Local\Temp\ipykernel_54376\3784479102.py:23: RuntimeWarning: overflow encountered in multiply
#   x[i+1] = x[i] + h * p_half
# C:\Users\marka\AppData\Local\Temp\ipykernel_54376\3784479102.py:23: RuntimeWarning: invalid value encountered in add
#   x[i+1] = x[i] + h * p_half

# %%
x
# Out:
# array([[ -1. ],
#        [  6.5],
#        [-44.5],
#        ...,
#        [  nan],
#        [  nan],
#        [  nan]])

# %%
plt.plot(x, p)
plt.show()
