# %%
import numpy as np
import matplotlib.pyplot as plt
import helpers as hp

# %% [markdown]
# here we investigate the stability threshold of the leapfrog integrator on a harmonic oscillator for various $\omega$ .

# %%
ws = np.linspace(1, 10, 20)
thresholds = [hp.get_stability_threshold(lambda x: -w**2 * x) for w in ws]
# Out:
# c:\Users\marka\OneDrive\Documents\Uni\Edinburgh Uni\RSCAM\S2 group proj\IPS\scripts\harmonic_oscillator\helpers.py:25: RuntimeWarning: overflow encountered in multiply
#   x[i+1] = x[i] + h * p_half
# c:\Users\marka\OneDrive\Documents\Uni\Edinburgh Uni\RSCAM\S2 group proj\IPS\scripts\harmonic_oscillator\helpers.py:25: RuntimeWarning: invalid value encountered in add
#   x[i+1] = x[i] + h * p_half
# C:\Users\marka\AppData\Local\Temp\ipykernel_12920\403793460.py:2: RuntimeWarning: overflow encountered in multiply
#   thresholds = [hp.get_stability_threshold(lambda x: -w**2 * x) for w in ws]
# c:\Users\marka\OneDrive\Documents\Uni\Edinburgh Uni\RSCAM\S2 group proj\IPS\scripts\harmonic_oscillator\helpers.py:26: RuntimeWarning: invalid value encountered in add
#   p[i+1] = p_half + h/2 * f(x[i+1])

# %%
plt.scatter(ws, thresholds, label = "data")
plt.plot(ws, 2/ws, label = "$h^* = 2/\omega$")
plt.xlabel("$\omega$")
plt.ylabel("$h^*$")
plt.legend()
plt.show()
